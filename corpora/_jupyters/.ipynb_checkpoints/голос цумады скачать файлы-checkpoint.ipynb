# %%
import os
import re
import json
from tqdm import tqdm
from pyperclip import copy as copy_2cb
from lingua import Language, LanguageDetectorBuilder
import fitz

# %%
# порезать на строки, удалить пустые строки
def cut_to_lines(text)
lines = list(filter(lambda t: t != '', text_1.split('\n')))
concated_lines = []
buffer = ''
w_buffer = ''
for line in lines:
    if line[-1] == '-':
        w_buffer = line.split()[-1][:-1]
        buffer += line[:-1]
    elif len(line.split()):
        if w_buffer and (w_buffer + line.split()[0] in ff):
            concated_lines.append(buffer[:-1] + line)
            print(w_buffer + '-' + line.split()[0] + ' IN DICT')
        else: 
            if w_buffer:
                print(w_buffer + '-' + line.split()[0] + ' NOT IN DICT')
                concated_lines.append(buffer)
            concated_lines.append(line)
        buffer = ''
        w_buffer = ''

# %%
all_numbers = list(filter(lambda t: t.endswith('.pdf'), os.listdir(r"C:\avar\Avar_BERT\corpora\_jupyters\golos_tsumada\pdf")))
for i in all_numbers[1:]:
    print(i)
    ! "C:\Program Files (x86)\ABBYY FineReader 15\FineCmd.exe" "C:\avar\Avar_BERT\corpora\_jupyters\golos_tsumada\pdf\{i}" /out "C:\volina092_files\golos\{i}.txt" /quit
# Out:
# № 10 19032021.pdf
# № 11 26032021.pdf
# № 12 02042021.pdf
# № 14  16042021.pdf
# № 15 23042021.pdf
# № 16 30042021.pdf
# № 19 28052021.pdf
# № 2 22012021.pdf
# № 21 10052019.pdf
# № 22 17052019.pdf
# № 24 31052019.pdf
# № 25 07062019.pdf
# № 26 14062019.pdf
# № 27 21062019.pdf
# № 29 06082021.pdf
# № 3 29012021.pdf
# № 30-31 10072020.pdf
# № 32 17072020.pdf
# № 34 02082019.pdf
# № 34 10092021.pdf
# № 35 09082019.pdf
# № 35 19082022.pdf
# № 35-36 07082020.pdf
# № 36 08092023.pdf
# № 36 26082022.pdf
# № 37 02092022.pdf
# № 37 14082020.pdf
# № 38 09092022.pdf
# № 38 21082020.pdf
# № 38 22092023.pdf
# № 39 29092023.pdf
# № 39-40.pdf
# № 4 27012023.pdf
# № 40  06102023.pdf
# № 41 04092020.pdf
# № 41 13102023.pdf
# № 42 11092020.pdf
# № 43 18092020.pdf
# № 44  03112023.pdf
# № 44 22102022.pdf
# № 44 25092020.pdf
# № 45 02102020.pdf
# № 46 09102020.pdf
# № 46 17112023.pdf
# № 47 16102020.pdf
# № 48 23102020.pdf
# № 48-49 01122023.pdf
# № 49 30102020.pdf
# № 50 06112020.pdf
# ...
