# %%
import requests
from bs4 import BeautifulSoup as bs
import re
import json
import time
from tqdm import tqdm
from pyperclip import copy as copy_2cb
import PyPDF2
from lingua import Language, LanguageDetectorBuilder
import fitz

# %%
url_list_release = 'http://www.mo-tsumada.ru/index.php/2-uncategorised/661-gazeta-golos-tsumady'
url_beginning = 'http://www.mo-tsumada.ru'

# %%
# получить список выпусков
releases = []
req = requests.get(url_list_release)
# req.encoding = 'windows-1251'
soup = bs(req.text, 'html.parser')

# %%
releases = [url_beginning + elem['href'] for elem in soup.find_all('a', {'class': 'at_url'})]
# == [elem['href'] for elem in soup.find_all('a', {'class': 'at_icon'})]

# %%
def get_title_from_url(url): return url[url.rfind('/') + 1:]

# %%
releases[0]
# Out:
# 'http://www.mo-tsumada.ru/attachments/article/661/№21 19042024.pdf'

# %%
# url = releases[0]

for url in releases:
    response = requests.get(url)
    with open('golos_tsumada/pdf/' + get_title_from_url(url), 'wb') as file:
        file.write(response.content)

# %% [markdown]
# ##### Работа над PDF 1 вариант

# %%
# Открываем PDF-файл
def get_rel_text(rel_title):
    with open('golos_tsumada/pdf/' + rel_title, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        rel_pages = []
        for page in reader.pages:
            # print(page.extract_text())
            rel_pages.append(page.extract_text())
        return rel_pages 
        # print(reader.pages[0].extract_text())

# %%
with open('голос цумады_0_все выпуски_без 249, 257.json', 'w', encoding='utf-8') as outfile:
    json.dump(all_rels_pages, outfile, ensure_ascii = False)

# %%
all_rels_pages = dict()
for i in tqdm(range(257, len(releases))):
    all_rels_pages[releases[i]] = get_rel_text(get_title_from_url(releases[i]))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 97/97 [00:50<00:00,  1.90it/s]

# %%
# from pdfminer.high_level import extract_text

# text = extract_text('golos_tsumada/pdf/' + get_title_from_url(releases[0]))

# print(repr(text))

# %%
file_ex = 'golos_tsumada/pdf/' + get_title_from_url(releases[0])

# %%
# без лишних пробелов
# from io import StringIO
# from pdfminer.high_level import extract_text_to_fp

# output_string = StringIO()

# with open(file_ex, 'rb') as fin:
#     extract_text_to_fp(fin, output_string)
# print(output_string.getvalue().strip())

# %%
from io import StringIO

from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser

output_string = StringIO()
with open(file_ex, 'rb') as in_file:
    parser = PDFParser(in_file)
    doc = PDFDocument(parser)
    rsrcmgr = PDFResourceManager()
    device = TextConverter(rsrcmgr, output_string, laparams=LAParams())
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    for page in PDFPage.create_pages(doc):
        interpreter.process_page(page)
    # print(dir(interpreter))    
# print(output_string.getvalue())
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'argstack', 'csmap', 'ctm', 'curpath', 'device', 'do_B', 'do_BDC', 'do_BI', 'do_BMC', 'do_BT', 'do_BX', 'do_B_a', 'do_CS', 'do_DP', 'do_Do', 'do_EI', 'do_EMC', 'do_ET', 'do_EX', 'do_F', 'do_G', 'do_ID', 'do_J', 'do_K', 'do_M', 'do_MP', 'do_Q', 'do_RG', 'do_S', 'do_SC', 'do_SCN', 'do_TD', 'do_TJ', 'do_TL', 'do_T_a', 'do_Tc', 'do_Td', 'do_Tf', 'do_Tj', 'do_Tm', 'do_Tr', 'do_Ts', 'do_Tw', 'do_Tz', 'do_W', 'do_W_a', 'do__q', 'do__w', 'do_b', 'do_b_a', 'do_c', 'do_cm', 'do_cs', 'do_d', 'do_f', 'do_f_a', 'do_g', 'do_gs', 'do_h', 'do_i', 'do_j', 'do_k', 'do_l', 'do_m', 'do_n', 'do_q', 'do_re', 'do_rg', 'do_ri', 'do_s', 'do_sc', 'do_scn', 'do_sh', 'do_v
# ...

# %% [markdown]
# ##### Работа над PDF 2 вариант

# %%
import sys
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.converter import XMLConverter, HTMLConverter, TextConverter
from pdfminer.layout import LAParams
import io

def pdfparser(data):

    fp = open(data, 'rb')
    rsrcmgr = PDFResourceManager()
    retstr = io.StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    # Create a PDF interpreter object.
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    # Process each page contained in the document.

    for page in PDFPage.get_pages(fp):
        interpreter.process_page(page)
        # print(interpreter.process_page(page))
        
        data = retstr.getvalue()
        print(data)
        input()
    print(data)

# if __name__ == '__main__':
#     pdfparser(sys.argv[1])

# %%
import fitz # imports the pymupdf library
doc = fitz.open('golos_tsumada/pdf/№ 11 26032021.pdf') # open a document
# for page in doc: # iterate the document pages
  # text = page.get_text()

# %%
# doc[0].get_text()

# %% [markdown]
# ##### Работа над PDF 3 вариант

# %%
# dir(doc[0])
bloks = doc[0].get_text_blocks()

# %%
mb = dict()
for b in bloks:
    if b[2] not in mb:
        mb[b[2]] = []
    mb[b[2]].append(b[4])

# %%
mb
# Out:
# {491.49530029296875: ['Гьал къояз  районалъул \n',
#   'лъайкьеялъул \nуправлениялъ \n',
#   'ци\xad\n\xad\nпиалияб \nэтап. \nГьенир \n',
#   'Гьез бихьизабуна жидерго \n',
#   'биячIужу \nАсият \nАбакарова, \n',
#   'Хапипат МухIамадовалъе ва \nлъабабилеб \nбакIалде \nккана \n'],
#  491.49627685546875: ['Агъвали \nлъималазул \nахикь \n \n'],
#  488.9965515136719: ['тIобитIана \n«Лъаг1алил \nтар\xad\n'],
#  488.99456787109375: ['биячи-2021» \nреспубли\xad\nкая\xad\n'],
#  488.99407958984375: ['лъу\xad\nлаб \nконкурсалъул \nмуни\xad\n'],
#  488.9952697753906: ['гIа\xad\nхьал\xad\nлъана анкьго росдал лъи\xad\n'],
#  488.00189208984375: ['малазул аха\xad\nзул тарбияруччаби. \n'],
#  491.4964904785156: ['педагогикияб бажари, гьит1и\xad\nчалгун х1алт1изе бугеб  махщел, \nтIори\xad\nтIана лъималгун тадбирал.\n'],
#  491.4957275390625: ['КIиго батIияб номинациялда \n \n'],
# ...

# %% [markdown]
# другой способ

# %%
import fitz
# doc = fitz.open("PyMuPDF.pdf")
# page = doc[0]
all_infos = doc[0].get_text("dict", sort=True)
# print(all_infos)

# %%
all_infos['blocks'][10]['bbox']
# Out:
# (102.06710052490234, 307.3857421875, 301.51910400390625, 333.9638671875)

# %%
# print(all_infos['blocks'][12]['bbox'])
# print(all_infos['blocks'][12])
# all_infos['blocks'][12]['lines']
for line in all_infos['blocks'][12]['lines']:
    # print(line['spans'][0]['text'])
    print(line['spans'][0]['bbox'])
# Out:
# (352.8945007324219, 329.32843017578125, 565.7813720703125, 340.40264892578125)
# (352.8945007324219, 340.32843017578125, 565.7784423828125, 351.40264892578125)
# (352.8945007324219, 351.32843017578125, 565.783447265625, 362.40264892578125)
# (352.8945007324219, 362.32843017578125, 394.7335205078125, 373.40264892578125)
# (403.64752197265625, 362.32843017578125, 447.3294982910156, 373.40264892578125)
# (456.24249267578125, 362.32843017578125, 525.8405151367188, 373.40264892578125)
# (534.7535400390625, 362.32843017578125, 565.78955078125, 373.40264892578125)

	Трансферты						1	Объем дотаций	4375,0	4574,1	4574,1	100,0			
1	Объем дотаций	1288,0	1420,2	1420,2	100,0		2	Субвен. ВУС	261,0	261,0	261,0	100,0			
2	Субвен. ВУС	93,0	93,0	93,0	100,0			Итого	4636,0	4835,1	4835,1	100,0			
	Итого	1381,0	1513,2	1513,2	100,0										
								Всего доходов	5003,3	5202,4	5182,0	99,6			
								Расходы:							
	Всего доходов	1448,3	1580,5	1577,9	99,8										
							1	Аппарат	1774,3	1917,2	1917,2	100,0			
	Расходы:														
								в т.ч. зарплата	1148,1	1127,2	1127,2	100,0			
1	Аппарат	902,6	937,6	937,6	100,0										
							2	Проведение выборов	200,0	200,0	200,0				
	в т.ч. зарплата	564,6	548,2	548,2	100,0										
							3	Резервный фонд	50,0	0,0	0,0				
2	Проведение выборов	120,0	120,0	120,0											
							4	ВУС	261,0	261,0	261,0	100,0			
3	ВУС	93,0	83,0	93,0	112,0										
								в т.ч. зарплата	167,4	167,4	167,4	100,0			
	в т.ч. зарплата	67,0	67,0	67,0	100,0										
							5  6	ЖКХ  Молодёжная политика	1420,0  25,0	1764,7	1764,7	100,0			
4	ЖКХ	82,5	144,1	144,1	100,0										
5	Культура	205,2	229,8	229,8	100,0										
							7	Культура	1133,0	1094,5	1094,5	100,0			
	в т.ч. зарплата	157,6	154,9	154,9	100,0										
								в т.ч. зарплата	724,0	724,0	724,0	100,0			
6	ФК и спорт	10,0	10,0	10,0	100,0										
							8	ФК и спорт	50,0	25,0	25,0	100,0			
	Всего расходов	14133	15245	15345	100,7										
								Всего расходов	4913,3	5262,4	5262,4	100,0			
															
	в т.ч. зарплата	7892	7701	7701	100,0			в т.ч. зарплата	20395	20186	20186	100,0			
Председатель сельского Собрания сельского поселения «сельсовет Цумадинский»	Ш. Гасанов  БетIерав редактор	Редакциялъул  Малачдибиров	(издателасул) адрес: 368900  ГIубайдула СагIадулаевич	Дагъистан Республика,  2-52-44	ЦIумада район, Кьенгьара росу  Заводалъул къватI, 4  Жавабияй секретарь  Сажидова	«ЦIумадисезул гьаракь»  Зульфия АхIмадовна	газета гIуцIарал:  «ЦIумада район» муниципалияб  2-52-92	районалъул администрация							Председатель сельского Собрания сельского поселения «сельсовет Тиндинский»	М. Магомедов  Газета къватIибе биччана	Тираж - 1346  «Издательский дом «Дагестан»	Газеталъул индекс:  ГАУялъул типографиялда.	51377 (бащдаб лъагIалие)  63302 (лъагIалие) Адрес: 367018,  МахIачхъала шагьар,	Макъалабазда рехсарал  Насрудиновасул проспект, 1 «А»	хIужабазул, тарихазул балъголъи  гъорлъ бугел ва цогидалги баяназул жаваб авторас кьола.								'''

# %%
lines = list(filter(lambda t: t != '' and t.count(' ') > 7, text.split('\n')))

# %%
# lines

# %%
concated_lines = []
buffer = ''
for line in lines:
    if line[-1] not in ['.', '?', '!']:
        buffer += line + ' '
    else:
        concated_lines.append(buffer + line)
        buffer = ''

# %%
# concated_lines

# %%
hi = 'hiiii'
tmp = "C:\Program Files (x86)\ABBYY FineReader 15\FineCmd.exe"
for i in range(2):
    ! echo {tmp + str(i)}
# Out:
# C:\Program Files (x86)\ABBYY FineReader 15\FineCmd.exe0
# C:\Program Files (x86)\ABBYY FineReader 15\FineCmd.exe1

# %%
'str'.endswith('r')
# Out:
# True

# %%
# import os
# beg = 'dsfsdf'
# all_numbers = list(filter(lambda t: t.endswith('.pdf'), os.listdir(r"C:\avar\Avar_BERT\corpora\_jupyters\golos_tsumada\pdf")))
# for i in all_numbers:
#     ! echo {beg + i}

# %%
!"C:\Program Files (x86)\ABBYY FineReader 15\FineCmd.exe" "C:\avar\Avar_BERT\corpora\_jupyters\golos_tsumada\pdf\№ 3 29012021.pdf" /out "C:\volina092_files\golos\№ 3 29012021.txt" /quit

# %%
text_1 = '''ЦIумадисезул гьаракь

Ассаламу гIалайкум!

2021 соналъул 29 январь Рузман №3 (7659) Газета бахъизе байбихьана 1937 соналъул 1 декабралда Багьа 8 гъурущ 12 +



ЦIУМАДА РАЙОНАЛЪУЛ ГАЗЕТА - ЦУМАДИНСКАЯ РАЙОННАЯ ГАЗЕТА

COVID -19

Вакцинация байбихьана

Коронавирусалде дан-де вакцинация гьаби… Гьеб ккола жакъа гIадамазда гьор-кьоб гIемер бицунеб суал.

Европаялъул лъебералда цо пачалихъалда байбихьун буго вакцинаби гьаризе. Хьул буго, гьединаб багъа-бачариялдалъун эпидемия чIезабизе кIвелин.

Россиялъул Прези-дент Владимир Путинил тIадкъаялда рекъон, улкаял-даго гIадин, Дагъистанал-даги байбихьана коронави-русалъул инфекциялдаса цIунизелъун прививкаби гьа-ризе.

Итни къоялъ нилъер рай-оналдаги гьеб макруяб ва захIматаб унтуде данде при-вивкаби гьаризе байбихьана.

Райбольницаялъул бетIе-

рав тохтур Хейруланам Ди-бирасулаевасул рагIабазда рекъон райбольницаялда прививкаби гьаризе гIуцIун руго киналниги шартIал, вакцинаби цIунун руго холо-дильниказда, прививка гьа-билелде цебе хал гьабулеб буго гьеб гьабизе вачIарасул сахлъиялъул.

ТIоцере прививкаби гьа-руна больницаялъул нух-малъулезе, отделениябазул нухмалъулезе, хехаб куме-калъул ва провизорнияб от-делалъул хIалтIухъабазе, участкаялъу лал тохтурзаба-зе. Прививка гьабурасда ха-дуб врачас бащадаб сагIаталъ гьенибго хал ккола.

Жакъа къоялде привив-каби гьаруразул чорхолъ киналгIаги хиса-басиял кке-

чIин абуна райбольницая-лъул бетIерав тохтурасги.

Прививка гьабулеб буго чIобого, жидеего бокьун. Гьел гьариялъул мурадги ккола вирусалде данде лага-черхалъул хIалкIолъи (им-мунитет) лъугьинаби.

Гьелда сверухъ хал-къалъул руго батIи-батIиял пикраби. Специалистаз гьеб рикIкIунеб буго захIматаб унтудаса гIадамал цIунизе бищун лъикIаб нухлъун.

Прививка гьабизе бегьу-ла балугълъиялдеги вахарав,

18-60 сонил гIумруялда ву-гев, гьеб гьабилелде кIи го анкьалъ ОРВИялъги унти-чIев, унтулевги гьечIев, COVID-19 вирусалде данде лага-черхалъулъ гьелъие чи-яраллъун кколел жал жани-ре лъугьингун рижулел ва гьезда данде чIарал веще-ствабиги (антитела) гьечIев чиясе.

        if w_buffer and (w_buffer + line.split()[0] in ff):
            concated_lines.append(buffer[:-1] + line)
            print(w_buffer + '-' + line.split()[0] + ' IN DICT')
        else: 
            if w_buffer:
                print(w_buffer + '-' + line.split()[0] + ' NOT IN DICT')
                concated_lines.append(buffer)
            concated_lines.append(line)
        buffer = ''
        w_buffer = ''
# Out:
# бетIе-рав IN DICT
# кке-чIин IN DICT
# ун-тиялдаса IN DICT
# ра-зилъун NOT IN DICT
# Па-анкьги NOT IN DICT
# ц1ал-дохъан IN DICT

# %%
# concated_lines

# %%
# удалить \xad
res = []
for line in concated_lines:
    res_line = []
    for w in line.split():
        if '-' in w and w.replace('-', '') in ff:
            res_line.append(w.replace('-', ''))
        else: res_line.append(w)
    res.append(' '.join(res_line))

# %%
# удалить короткие куски
lines = list(filter(lambda t: t.count(' ') > 7, res))
# lines

# %%
# поправить вручную
# with open('tmp.json', 'w', encoding='utf-8') as f:
#     json.dump({'lines': lines}, f, ensure_ascii=False, indent=4)

# %%
def isUpper(line):
    if not line: return False 
    return bool(re.match(r'[А-Я]', line[0]))

# %%
# соединить разорванные предложения
concated_lines = []
buffer = ''
for line in lines:
    if line[-1] not in ['.', '!', '?']:
        buffer += line + ' '
    elif not isUpper(line[0]):
        if buffer or line[0].isdigit():
            concated_lines.append(buffer + line)
            buffer = ''
        else: print('alarm start lower: ' + line[:20])
    else:
        if buffer:
            print('alarm after buffer ' + line[:29])
            # concated_lines.append(buffer)
        concated_lines.append(line)
        buffer = ''
# Out:
# alarm after buffer Коронавирусалде данде вакцина
# alarm start lower: ре къон 5-8 классазу
# alarm after buffer Бюджет администрации сельског
# alarm after buffer Каждый вторник с 10:00 до 12:
# alarm after buffer Цинги ЖабрагIил вахъана ва Ах
# alarm start lower: -Щив мунилан гьикъан
# alarm after buffer В соответствии с Постановлени
# alarm start lower: тIагIинабиялъе грейд
# alarm after buffer Макъалабазда рехсарал хIужаба

# %%
# lines
concated_lines[2]
# Out:
# 'Россиялъул Президент Владимир Путинил тIадкъаялда рекъон, улкаялдаго гIадин, Дагъистаналдаги байбихьана коронавирусалъул инфекциялдаса цIунизелъун прививкаби гьаризе.'

# %%
from langdetect import detect_langs
import numpy as np
def langdetect_ru_conf(line):
    guesses = {guess.lang: guess.prob for guess in detect_langs(line)}
    if not 'ru' in guesses: guesses['ru'] = 0
    return np.round(guesses['ru'], 3)
def lingua_ru_conf(line):
    dtctr_ru_conf = detector.compute_language_confidence(line, Language.RUSSIAN)
    if dtctr_ru_conf < 0.01: dtctr_ru_conf = 0.01
    return np.round(dtctr_ru_conf, 4)

# %%
res = []
for line in concated_lines:
    ld_ru_conf = langdetect_ru_conf(line)
    dtctr_ru_conf = lingua_ru_conf(line)
    if (ld_ru_conf > 0.8 and dtctr_ru_conf > 0.8): print(line[:50])
    else: res.append(line)
res
with open('golos_tsumada_test.json', 'w', encoding='utf-8') as f:
    json.dump({'texts': res}, f, ensure_ascii=False)
# Out:
# Бюджет администрации сельского поселения «сельсове
# Бюджет администрации сельского поселения «сельсове
# Каждый вторник с 10:00 до 12:00 совещание с участи
# Каждый последний вторник месяца с 10:00 до 12:00 с
# В соответствии с Постановлением Правительства РФ о
# Документы и личные фотографии для получения или за
# Ответственность за несвоевременное оформление пасп
# Родители (законные представители), в случае несвое
# К административной ответственности по части 1 стат
# Заявитель, которому не исполнилось шестнадцати лет
# Важнейшая проблема, с которой сталкивается многие
# Мошенники, выдают себя за сотрудников банка, сообщ
# Злоумышленники в своих преступных целях используют
# Аналогичная предостерегающая информация опубликова
# С 25 января 2021 года возобновлен прием и обслужив
# При посещении налоговой инспекции необходимо соблю
# А так же рекомендуем все вопросы с налоговым орган

# %%
# detector = LanguageDetectorBuilder.from_all_languages_with_cyrillic_script().build()
# for line in concated_lines:
#     print(line[:30])
#     result = detector.detect_language_of(line)
# # print(f"{result.language.name}: '{sentence[result.start_index:result.end_index]}'")
#     conf = detector.compute_language_confidence(line, Language.RUSSIAN)
#     print(str(result) + '\t' + str(conf))

# %%
path = r"C:\avar\Avar_BERT\corpora\_jupyters\golos_tsumada\pdf\№ 3 29012021.pdf"

# %% [markdown]
# Составление словаря с помощью fitz (чтобы удалить переносы строк)

# %%
import fitz
def doc_dict_from_fitz(path):
    doc = fitz.open(path)
    doc_dict = []
    for page in doc:
        all_infos = page.get_text_blocks()
        res = ' '.join([elem[4] for elem in all_infos]).replace('\xad\n ', '').replace('\xad\n', '').replace('\n', ' ')
        doc_dict += res.split()
    return set(doc_dict)

# %%
ff = doc_dict_from_fitz(r"C:\avar\Avar_BERT\corpora\_jupyters\golos_tsumada\pdf\№ 3 29012021.pdf")

# %%
# res = ' '.join([elem[4] for elem in all_infos]).replace('\xad\n ', '').replace('\xad\n', '').replace('\n', ' ')
# res.split()

# %%
ff
# Out:
# {'UFT',
#  'ежедневно,',
#  'призеразе',
#  'кIиазарго',
#  'главами',
#  'Абасов',
#  'ХIажиев',
#  'канлъигIан',
#  'тарихалъул',
#  'представители).',
#  'керен-ракIги',
#  'гьединаб',
#  'Нураниял',
#  'цевесан',
#  'редактор',
#  'халккун',
#  'Араб',
#  'нусиялда',
#  '38',
#  'лазатаб',
#  'халкъалъухъе',
#  'витIарав',
#  'налогоплательщиков',
#  'рекъон,',
#  'бокьараб',
#  'гьарула',
#  'авторас',
#  'ХIабибасе',
#  'ГIабдулхIакъов',
#  'бай»-абун.',
#  '1651,9',
#  'гьесда',
#  'Давудов',
#  'доходов',
#  'борлъун,',
#  'Абакаров',
#  'ХIасанов',
#  'тIубазабуна,',
#  'Злоумышленники',
#  'сахлъиялъе',
#  'Озденг',
#  'авараглъунги',
#  'района',
#  'Эчеда',
#  'предостерегающая',
#  'РФ.',
#  'гь.ц.',
#  '10:00',
#  '822,6',
#  'чIарал',
#  'ПатIиматица,',
#  '114,0',
#  'ХIабибулагь,',
#  'бачIараб',
#  'Магомеднабиев,',
#  'чего',
#  'цеве',
#  'цинги',
#  '1413,0',
#  'нухмалъулей',
#  '990,0',
#  'выходных',
#  'цадахъгун',
#  '1596,0',
#  'февралалда',
# ...
